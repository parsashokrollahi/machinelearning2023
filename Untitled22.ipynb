# %% [markdown]
# <a href="https://colab.research.google.com/github/parsashokrollahi/machinelearning2023/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

def membership1(u):
    if -1 <= u <= 1:
        return 1 - abs(u)
    else:
        return 0

def membership2(u):
    if 0 <= u <= 2:
        return 1 - abs(u-1)
    else:
        return 0

u = [i/100 for i in range(-100, 201)]
plt.plot(u, [membership1(i) for i in u], label='$\mu_{A_1}$')
plt.plot(u, [membership2(i) for i in u], label='$\mu_{A_2}$')
plt.text(0, 0, r'$\bar{y}^1=0$', fontsize=15)
plt.text(1, 0, r'$\bar{y}^2=1$', fontsize=15)
plt.legend()
plt.grid(True)
plt.savefig('fuzzy960.svg')
plt.show()

# %%
! pip install anfis
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894077 sha256=459720d049b88613e7c516c26dbc58fe31b40f6cdd64819ae89fd9647717ef3b
#   Stored in directory: /root/.cache/pip/wheels/4f/86/1b/dfd97134a2c8313e519bcebd95d3fedc7be7944db022094bc8
# Successfully built scikit-fuzzy
# ...

# %%
# !gdown 18CtveD31k3_95db7j_E4NbOOiWcUQxLz
# Out:
# Access denied with the following error:
#
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=18CtveD31k3_95db7j_E4NbOOiWcUQxLz

# %%
import ANFIS
import numpy as np
import math
from matplotlib import pyplot
import seaborn as sns
sns.set()
from matplotlib import rcParams
rcParams['figure.figsize'] = 10,7
def Randomize(qnt1,qnt2):
    sample_aa = []
    sample_aa = list(np.random.random(qnt1)*8)
    for i in np.random.random(qnt2)*-8:
        sample_aa.insert(0,i)
    sample_bb = []
    sample_bb = list(np.random.random(qnt1)*8)
    for i in np.random.random(qnt2)*-8:
        sample_bb.insert(0,i)



    global output
    global inputs
    output = []
    inputs = []
    for i,ii in zip(sample_aa,sample_bb):
        inputs.append([i,ii])
        output.append((math.sin(i)/i)*(math.sin(ii)/ii))

    return inputs,output
    def Randomize(qnt1,qnt2):
    sample_aa = np.random.uniform(-10,10,qnt1)
#     sample_aa = list(np.random.random(qnt1)*8)
#     for i in np.random.random(qnt2)*-8:
#         sample_aa.insert(0,i)
#     sample_bb = []
#     sample_bb = list(np.random.random(qnt1)*8)
#     for i in np.random.random(qnt2)*-8:
#         sample_bb.insert(0,i)

    sample_bb = np.random.uniform(-10,10,qnt2)

    global output
    global inputs
    output = []
    inputs = []
    for i,ii in zip(sample_aa,sample_bb):
        inputs.append([i,ii])
        output.append((math.sin(i)/i)*(math.sin(ii)/ii))

    return inputs,output
# Out:
#   File "<ipython-input-4-79eae93f4ce9>", line 31
#     sample_aa = np.random.uniform(-10,10,qnt1)
#     ^
# IndentationError: expected an indented block after function definition on line 30

# %%
b = ANFIS.ANFIS(function=2,model=[2,1],Gamma= 10**6,lam = 0.98,delta=1)
# Randomize(60,61)
a = ANFIS.ANFIS(function=2,model=[2,1],Gamma= 10**6,lam = 0.98,delta=1)
a.train(inputs,output,interval = [-10,10], width = 12,e=10**-17,generations=250,learningRate=0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-28072ed7f035> in <cell line: 1>()
# ----> 1 b = ANFIS.ANFIS(function=2,model=[2,1],Gamma= 10**6,lam = 0.98,delta=1)
#       2 # Randomize(60,61)
#       3 a = ANFIS.ANFIS(function=2,model=[2,1],Gamma= 10**6,lam = 0.98,delta=1)
#       4 a.train(inputs,output,interval = [-10,10], width = 12,e=10**-17,generations=250,learningRate=0.1)
#
# NameError: name 'ANFIS' is not defined
