# %% [markdown]
# <a href="https://colab.research.google.com/github/parsashokrollahi/machinelearning2023/blob/main/HW1_2_Python_Tutorial_2-parsa-shokrollahi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem 1:** Create a NumPy array of 20 random integers between 1 and 100. Calculate the mean, median, and standard deviation of the array.

# %%
import numpy as np

a = np.random.randint(1, 101, size = 20)
mean = np.mean(a)
med = np.median(a)
std = np.std(a)
print(mean,med,std)
# Out:
# 55.5 56.5 26.38086427697167

# %% [markdown]
# **Problem 2:** Create a Pandas DataFrame with three columns - 'Name', 'Age', and 'City' - and at least five rows of data. Perform a basic data exploration by displaying the first 3 rows, the last 2 rows, and a summary of statistics for the 'Age' column.

# %%
import pandas as pd
data = {
    'Name': ['Parsa', 'Amir', 'Mohammad', 'Mohsen', 'Mobin'],
    'Age': [21, 23, 22, 22, 20],
    'City': ['Semnan', 'Semnan', 'Shahrekord', 'Damghan', 'Hamedan']
}

df = pd.DataFrame(data)
print("First 3 rows:",df.head(3),"\nLast 2 rows:",df.tail(2),"\nSummary statistics for 'Age' column:",df['Age'].describe())
# Out:
# First 3 rows:        Name  Age        City
# 0     Parsa   21      Semnan
# 1      Amir   23      Semnan
# 2  Mohammad   22  Shahrekord
# Last 2 rows:      Name  Age     City
# 3  Mohsen   22  Damghan
# 4   Mobin   20  Hamedan
# Summary statistics for 'Age' column: count     5.000000
# mean     21.600000
# std       1.140175
# min      20.000000
# 25%      21.000000
# 50%      22.000000
# 75%      22.000000
# max      23.000000
# Name: Age, dtype: float64

# %% [markdown]
# **Problem 3:** Create a bar chart using Matplotlib to visualize the following data: Monthly sales for a store (January to May). Use appropriate labels and titles for the chart.

# %%
import matplotlib.pyplot as plt

months = ['Farvadin', 'Ordibehesht', 'KHordad', 'Tir', 'Mordad']
sales = [5000000, 6400000, 1000000, 3000000, 10000000]
plt.figure(figsize=(8, 6))
plt.bar(months, sales, color='skyblue')
plt.xlabel('Month')
plt.ylabel('Sales (in Rials)')
plt.title('Monthly Sales  ')
plt.grid(axis='y', linestyle='--', alpha=1)
plt.show()

# %% [markdown]
# **Problem 4:** Create two NumPy arrays, 'arr1' and 'arr2', both of size 5x5 with random integer values. Perform element-wise addition, subtraction, multiplication, and division between the two arrays.

# %%
import numpy as np

arr1 = np.random.randint(1, 100, size=(5, 5))
arr2 = np.random.randint(1, 100, size=(5, 5))
addition = arr1 + arr2
subtraction = arr1 - arr2
multiplication = arr1 * arr2
division = arr1 / (arr2 + 1e-6)
print("Array 1 ",arr1,"\nArray 2:",arr2)
print("Addition:",addition,"\nSubtraction",subtraction,"\nMultiplication:",multiplication,"\nDivision:",division)
# Out:
# Array 1  [[59 29 36 24  4]
#  [47 91 94 47 47]
#  [97 44 73 53 60]
#  [97 44 38 33 10]
#  [87 72 21  4 62]]
# Array 2: [[21  8 64 71 20]
#  [33 30  4 74 91]
#  [66 74 52 46 87]
#  [61 70  5 21 70]
#  [85 83  4 95 97]]
# Addition: [[ 80  37 100  95  24]
#  [ 80 121  98 121 138]
#  [163 118 125  99 147]
#  [158 114  43  54  80]
#  [172 155  25  99 159]]
# Subtraction [[ 38  21 -28 -47 -16]
#  [ 14  61  90 -27 -44]
#  [ 31 -30  21   7 -27]
#  [ 36 -26  33  12 -60]
#  [  2 -11  17 -91 -35]]
# Multiplication: [[1239  232 2304 1704   80]
#  [1551 2730  376 3478 4277]
#  [6402 3256 3796 2438 5220]
#  [5917 3080  190  693  700]
#  [7395 5976   84  380 6014]]
# Division: [[ 2.80952368  3.62499955  0.56249999  0.33802816  0.19999999]
#  [ 1.42424238  3.03333323 23.49999413  0.63513513  0.51648351]
#  [ 1.46969695  0.59459459  1.40384613  1.15217389  0.68965516]
#  [ 1.59016391  0.62857142  7.59999848  1.5714285   0.14285714]
#  [ 1.0235294   0.86746987  5.24999869  0.04210526  0.63917525]]

# %% [markdown]
# **Problem 5:** Given a Pandas DataFrame with information about employees, filter and display only the employees who are older than 30 years.

# %%
import pandas as pd


data = {'Name': ['Ali', 'Hassan', 'Hosein', 'Sajad', 'Mahdi'],
        'Age': [28, 25, 40, 29, 20],
        'Department': ['Dr', 'Student', 'PHD', 'Dr', 'student']}

employee_df = pd.DataFrame(data)
older_than_30 = employee_df[employee_df['Age'] > 30]
print(older_than_30)
# Out:
#      Name  Age Department
# 2  Hosein   40        PHD

# %% [markdown]
# **Problem 6:** Create a scatter plot using Matplotlib to visualize a dataset of 100 random (x, y) coordinates. Label the axes appropriately and give the plot a title.

# %%
import matplotlib.pyplot as plt
import numpy as np


np.random.seed(0)
x = np.random.rand(100)
y = np.random.rand(100)
plt.figure(figsize=(8, 5))
plt.scatter(x, y, c='black', marker='o', s=30, alpha=0.7)
plt.xlabel('X-coordinate')
plt.ylabel('Y-coordinate')
plt.title('Scatter of random coordinate')
plt.grid(True)
plt.show()

# %% [markdown]
# **Problem 7:** Create two NumPy matrices, 'matrix1' (2x3) and 'matrix2' (3x4), with random values. Perform matrix multiplication between the two matrices.

# %%
import numpy as np

mat1 = np.random.rand(2, 3)
mat2 = np.random.rand(3, 4)
mup = np.dot(mat1, mat2)
print("Matrix 1:\n",mat1,"\nMatrix 2:\n",mat2,"\nMatrix Multiplication:\n",mup)
# Out:
# Matrix 1:
#  [[0.31179588 0.69634349 0.37775184]
#  [0.17960368 0.02467873 0.06724963]]
# Matrix 2:
#  [[0.67939277 0.45369684 0.53657921 0.89667129]
#  [0.99033895 0.21689698 0.6630782  0.26332238]
#  [0.020651   0.75837865 0.32001715 0.38346389]]
# Matrix Multiplication:
#  [[0.9092489  0.57897454 0.74992045 0.60779543]
#  [0.14785052 0.13783905 0.13425656 0.19333173]]

# %% [markdown]
# **Problem 8:** Given a Pandas DataFrame containing sales data, calculate and display the total sales for each product category.

# %%
import pandas as pd

data = {'Product Category': ['Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics'],
        'Product Name': ['Laptop', 'T-Shirt', 'Smartphone', 'Jeans', 'Tablet'],
        'Sales Amount': [1200, 50, 800, 60, 400]}

sales_df = pd.DataFrame(data)
total_sales_by_category = sales_df.groupby('Product Category')['Sales Amount'].sum().reset_index()
print(total_sales_by_category)
# Out:
#   Product Category  Sales Amount
# 0         Clothing           110
# 1      Electronics          2400

# %% [markdown]
# **Problem 9:** Create a line chart using Matplotlib to visualize the population growth of a city over 10 years. Label the axes and provide a title.

# %%
import matplotlib.pyplot as plt


years = range(2000, 2011)
population = [50000, 60000, 70000,80000, 80000, 90000, 100000, 110000, 120000, 130000, 150000]

plt.figure(figsize=(8, 6))
plt.plot(years, population, marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('City Population Growth Over 10 Years')
plt.grid(True)
plt.show()

# %% [markdown]
# **Problem 10:** Given a Pandas DataFrame containing information about students, add a new column 'Grade' based on the following criteria:
# * If 'Score' >= 90, Grade is 'A'
# * If 'Score' >= 80, Grade is 'B'
# * If 'Score' >= 70, Grade is 'C'
# * If 'Score' < 70, Grade is 'D'

# %%
import pandas as pd
import numpy as np

data = {'Name': ['Ali', 'Sina', 'Iman', 'Mohsen', 'Kasra'],
        'Score': [90, 86, 72, 66, 50]}

student_df = pd.DataFrame(data)
conditions = [
    student_df['Score'] >= 90,
    (student_df['Score'] >= 80) & (student_df['Score'] < 90),
    (student_df['Score'] >= 70) & (student_df['Score'] < 80),
    student_df['Score'] < 70
]

grades = ['A', 'B', 'C', 'D']
student_df['Grade'] = np.select(conditions, grades, default='N/A')
print(student_df)
# Out:
#      Name  Score Grade
# 0     Ali     90     A
# 1    Sina     86     B
# 2    Iman     72     C
# 3  Mohsen     66     D
# 4   Kasra     50     D

# %% [markdown]
# **Problem 11:** You are given a dataset containing monthly sales data for three products (A, B, and C) over a two-year period. Your task is to perform various data analysis tasks using NumPy, Pandas, and Matplotlib.
#
#
# *   Dataset:
#
# ```
# import pandas as pd
#
# data = {
#     'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
#     'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
#     'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
#     'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
# }
#
# sales_df = pd.DataFrame(data)
# ```
# *  Tasks:
# 1. Calculate and display the total sales for each product over the two-year period.
#
# 2. Calculate and display the average monthly sales for each product.
#
# 3. Find the month with the highest sales for each product, and display the product and the sales value for that month.
#
# 4. Calculate and display the percentage change in sales for each product from January to December in the second year (2022).
#
# 5. Create a line chart using Matplotlib to visualize the monthly sales data for each product over the two-year period. Label the axes and provide a title for the chart.
#
# 6. Calculate the correlation between Product A and Product B sales. Is there a strong correlation between these two products? Display the correlation coefficient.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
    'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
    'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
    'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
}

sales_df = pd.DataFrame(data)

total_sales = sales_df.sum(numeric_only=True)
print("Total Sales for Each Product:\n",total_sales)
average_monthly_sales = sales_df.mean(numeric_only=True)
print("\nAverage Monthly Sales for Each Product:\n",average_monthly_sales)
max_sales_month = sales_df.iloc[:, 1:].idxmax()
print("\nMonth with Highest Sales for Each Product:")
for product, month in max_sales_month.iteritems():
    print(f"Product: {product}, Month: {month}, Sales: {sales_df.at[month, product]}")
january_2021 = sales_df['Month'][0].strftime('%Y-%m')
december_2022 = sales_df['Month'][23].strftime('%Y-%m')
sales_2021 = sales_df[sales_df['Month'].between(january_2021, december_2022)]
percentage_change_2022 = (sales_2021.iloc[11:23, 1:].pct_change().mean()) * 100
print("\nPercentage Change in Sales for Each Product in 2022:\n",percentage_change_2022)
correlation = sales_df['Product A Sales'].corr(sales_df['Product B Sales'])
print("\nCorrelation between Product A and Product B Sales:\n",correlation)

plt.figure(figsize=(12, 6))
plt.plot(sales_df['Month'], sales_df['Product A Sales'], label='Product A')
plt.plot(sales_df['Month'], sales_df['Product B Sales'], label='Product B')
plt.plot(sales_df['Month'], sales_df['Product C Sales'], label='Product C')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales Data Over Two Years')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Total Sales for Each Product:
#  Product A Sales    31600
# Product B Sales    23800
# Product C Sales    11510
# dtype: int64
#
# Average Monthly Sales for Each Product:
#  Product A Sales    1316.666667
# Product B Sales     991.666667
# Product C Sales     479.583333
# dtype: float64
#
# Month with Highest Sales for Each Product:
# Product: Product A Sales, Month: 23, Sales: 1900
# Product: Product B Sales, Month: 23, Sales: 1700
# Product: Product C Sales, Month: 23, Sales: 720
#
# Percentage Change in Sales for Each Product in 2022:
#  Product A Sales    2.423179
# Product B Sales    4.290826
# Product C Sales    3.490168
# dtype: float64
#
# Correlation between Product A and Product B Sales:
#  0.954652710589704
# <ipython-input-11-dfa7578f8e74>:19: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for product, month in max_sales_month.iteritems():
